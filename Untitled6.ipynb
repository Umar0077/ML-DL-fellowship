# %% [markdown]
# <a href="https://colab.research.google.com/github/Umar0077/ML-DL-fellowship/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize

def mse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred)

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

def softmax(x):
    exp_x = np.exp(x - np.max(x))  # Subtract max for numerical stability
    return exp_x / np.sum(exp_x)

# Sample Data for Linear Regression
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

# Linear Regression Model
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# Display Results
print("MSE:", mse(y, y_pred))
print("RMSE:", rmse(y, y_pred))
print("Cosine Similarity:", cosine_similarity(np.array([1, 2, 3]), np.array([4, 5, 6])))
print("Softmax Output:", softmax(np.array([2.0, 1.0, 0.1])))

# Plot Linear Regression
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Line')
plt.xlabel('X values')
plt.ylabel('y values')
plt.legend()
plt.show()
# Out:
# MSE: 0.47999999999999987
# RMSE: 0.6928203230275508
# Cosine Similarity: 0.9746318461970762
# Softmax Output: [0.65900114 0.24243297 0.09856589]
